# %% [markdown]
# # 第一題

# %%
import numpy as np
import matplotlib.pyplot as plt

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
def mean_squared_error(y,yp):
    """
   計算MSE
   Args:
        - y:
        - yp:
   Return:
       - mse: MSE
    """
    mse = MSE = sum((y-yp)**2)/len(y)
    return mse

w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 267.283
# The Mean absolute error is 13.211

# %% [markdown]
# # 第二題

# %% [markdown]
# [Kaggle Dataset](https://www.kaggle.com/datafiniti/womens-shoes-prices)
#
# 1. 此組資料可以決定鞋子品牌的價格是否要調整，也可以設計價錢制定的策略，甚至可以決定鞋子奢侈品的價格趨勢
# 2. 此資料為Datafiniti所提供，平台提供使用者快速查詢網站上的大量資料。資料為蒐集上千個網站的內容並建立一個
#    資料庫來整理。
# 3. 資料型態為varchar(n)、int、datetime、float(n)
# 4. 為了解分析女鞋價格訂定的規則、原因，可以將不同品牌做出一個平均的售價，或是找出平均單價偏高的品牌，也可以
#    找出哪個品牌擁有最廣的價格範圍。最後也能找出所有牌子的價錢是否有形成一個常態分布，或是對於特定的牌子鞋子
#    價格有無一個趨勢或特定分布。

# %% [markdown]
# # 第三題

# %% [markdown]
# 1. 假設網路上各平台各名人網紅的口碑與平台上的評分分數會直接影響業績，有多數平台、名人推薦或是關鍵字搜尋時能
#    在搜尋結果前幾個出現，增加能見度，推廣知名度可以提升業績。
# 2. 要搜尋自己車隊的評價可上各大知名社群平台(e.g FB、Dcard、IG、Twitter)，也可以上影音平台(e.g YT)，或是
#    論壇、Google Map等收集車隊評價，以及類似評分。
# 3. 資料型態為varchar(n)、int、datetime、float(n)
# 4. 可以將蒐集來的評分取平均；也可計數推薦人數，其中細分推薦的名人人數，哪個名人的推薦文或評分最多人觀看，可
#    以尋求名人合作代言提升知名度；計數各大平台廣告觸及率，推出相關折價券優惠，增加使用者人數。
